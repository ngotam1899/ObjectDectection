# %%
from imageai.Prediction.Custom import ModelTraining
model_trainer = ModelTraining()
model_trainer.setModelTypeAsResNet()
model_trainer.setDataDirectory("pets")
model_trainer.trainModel(num_objects=2, num_experiments=10, enhance_data=True, batch_size=10, show_network_summary=True)
# Out:
# Model: "model_9"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_10 (InputLayer)           [(None, 224, 224, 3) 0
# __________________________________________________________________________________________________
# conv2d_477 (Conv2D)             (None, 112, 112, 64) 9472        input_10[0][0]
# __________________________________________________________________________________________________
# batch_normalization_477 (BatchN (None, 112, 112, 64) 256         conv2d_477[0][0]
# __________________________________________________________________________________________________
# activation_450 (Activation)     (None, 112, 112, 64) 0           batch_normalization_477[0][0]
# __________________________________________________________________________________________________
# ...

# %%
# Luật của bộ train
# First, your batch size can't be more than the images in your test and train folders
# Secondly, you should have at least 300 for train and 100 for test per object to create a model with minimal viable accuracy.
